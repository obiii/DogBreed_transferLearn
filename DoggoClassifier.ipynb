# %%
import numpy as np
from keras.layers import Dropout
from sklearn.datasets import load_files    
from keras.utils import np_utils
from sklearn.metrics import classification_report
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.callbacks import ModelCheckpoint  
from keras.optimizers import SGD
import tensorflow as tf
import keras
import cv2
import os
import pandas as pd
import pdb
from keras.preprocessing.image import ImageDataGenerator

from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
transferModel = "xception"
trainDir = 'dogImages/train/'
valdDir = 'dogImages/valid/'
testDir = 'dogImages/test/'
img_width = img_height = 224
batch_size = 16

# %%
def renameDirs(path):
    dirs = os.listdir(path)
    basePath = os.getcwd()
    for ddir in dirs:
        if '.' in ddir:
            newdir = ddir.split('.')[1]
            os.rename(os.path.join(basePath,path,ddir), os.path.join(basePath,path,newdir))

# %%
renameDirs(trainDir)
renameDirs(valdDir)
renameDirs(testDir)

# %%
def get_nbSmaples(path):
    noOfFiles = 0
    for base, dirs, files in os.walk(path):
        for Files in files:
            noOfFiles += 1
    return(noOfFiles)

# %%
def computeBottleneckFeat(imagePath):
    model = keras.applications.Xception(weights='imagenet',include_top=False)
    im = cv2.resize(cv2.imread(imagePath), (img_width, img_height)).astype(np.float32)
    im = np.expand_dims(im, axis=0)
    im_transform = model.predict(im*1./255)
    print('Features Generated: ',im_transform.shape)
    return(im_transform)

# %%
def load_dataset(path,targ_names = False):
    data = load_files(path)
    dog_files = np.array(data['filenames'])
    dog_targets = np_utils.to_categorical(np.array(data['target']), 133)
    
    if targ_names:
        return dog_files, dog_targets,data['target_names']
    else:
        return dog_files, dog_targets

# %%
def predict(model, imagePath):
    
    feats = computeBottleneckFeat(imagePath)
    predict_proba = model.predict(feats)
    pred = predict_proba.argmax(axis=-1)[0]
    pred_label = train_target_names[pred]
    
    img = cv2.imread(testImage)
    img = cv2.putText(img, pred_label, (10,50), cv2.FONT_HERSHEY_SIMPLEX ,  
                       1, (255,0,0), 2, cv2.LINE_AA)
    cv2.imshow(pred_label,img)
    cv2.waitKey(0) # waits until a key is pressed
    cv2.destroyAllWindows() # destroys the window showing image

    
    return(pred_label)

# %%
def createModel(inputShape):
    
    # Model Creation
    Xception_model = Sequential()
    Xception_model.add(GlobalAveragePooling2D(input_shape=inputShape))
    Xception_model.add(Dense(500, activation='relu'))
    Xception_model.add(Dropout(0.4))
    Xception_model.add(Dense(133, activation='softmax'))
    Xception_model.summary()
    
    # Compile
    Xception_model.compile(loss='categorical_crossentropy', optimizer=SGD(lr=0.002), metrics=['accuracy'])
    return(Xception_model)

# %%
def trainModel(model):
    checkpointer = ModelCheckpoint(filepath='models/weights.best.Xception.hdf5', 
                               verbose=1, save_best_only=True)
    model.fit(train_Xception, train_targets, 
          validation_data=(valid_Xception, valid_targets),
          epochs=120, batch_size=20, callbacks=[checkpointer], verbose=1)
    return(model)

# %%
def loadModel(inputShape,weights):
    Xception_model = Sequential()
    Xception_model.add(GlobalAveragePooling2D(input_shape=inputShape))
    Xception_model.add(Dense(500, activation='relu'))
    Xception_model.add(Dropout(0.4))
    Xception_model.add(Dense(133, activation='softmax'))
    Xception_model.load_weights(weights)
    return(Xception_model)

# %%
def testModel(model,test_Xception,test_targets,test_target_names):
    Xception_predictions = [np.argmax(model.predict(np.expand_dims(feature, axis=0))) for feature in test_Xception]

    # evaluating on test data
    test_accuracy = 100*np.sum(np.array(Xception_predictions)==np.argmax(test_targets, axis=1))/len(Xception_predictions)
    print('Test accuracy: %.4f%%' % test_accuracy)
    targs = np.array(test_target_names)
    preds = list(targs[Xception_predictions])
    
    actual = np.argmax(test_targets,axis = 1)
    actual = np.array(actual)
    actual = list(targs[actual])
    
    print(classification_report(actual, preds, target_names=test_target_names))

# %%
train_files, train_targets, train_target_names = load_dataset('dogImages/train',True)
valid_files, valid_targets, valid_target_names= load_dataset('dogImages/valid',True)
test_files, test_targets, test_target_names= load_dataset('dogImages/test',True)

# %%
bottleneck_features = np.load('bottleneck_feat/DogXceptionData.npz')
train_Xception = bottleneck_features['train']
valid_Xception = bottleneck_features['valid']
test_Xception = bottleneck_features['test']
train_Xception.shape,test_Xception.shape,valid_Xception.shape
# Out:
# ((6680, 7, 7, 2048), (836, 7, 7, 2048), (835, 7, 7, 2048))

# %%
xceptionModel = createModel(train_Xception.shape[1:])
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_4 ( (None, 2048)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 500)               1024500
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 133)               66633
# =================================================================
# Total params: 1,091,133
# Trainable params: 1,091,133
# Non-trainable params: 0
# _________________________________________________________________

# %%
xceptionModel = loadModel(train_Xception.shape[1:],'models/weights.best.Xception.hdf5')
xceptionModel.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               1024500
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 133)               66633
# =================================================================
# Total params: 1,091,133
# Trainable params: 1,091,133
# Non-trainable params: 0
# _________________________________________________________________

# %%
xceptionModel = trainModel(xceptionModel)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/120
# 6680/6680 [==============================] - 4s 542us/step - loss: 4.7961 - accuracy: 0.0323 - val_loss: 4.5415 - val_accuracy: 0.1269
#
# Epoch 00001: val_loss improved from inf to 4.54151, saving model to models/weights.best.Xception.hdf5
# Epoch 2/120
# 6680/6680 [==============================] - 3s 493us/step - loss: 4.3862 - accuracy: 0.1401 - val_loss: 4.1457 - val_accuracy: 0.3449
#
# Epoch 00002: val_loss improved from 4.54151 to 4.14571, saving model to models/weights.best.Xception.hdf5
# Epoch 3/120
# 6680/6680 [==============================] - 3s 493us/step - loss: 3.9723 - accuracy: 0.3058 - val_loss: 3.7109 - val_accuracy: 0.4946
#
# Epoch 00003: val_loss improved from 4.14571 to 3.71089, saving model to models/weights.best.Xception.hdf5
# Epoch 4/120
# 6680/6680 [==============================] - 3s 492us/step - loss: 3.5283 - accuracy: 0.4290 - val_loss: 3.2466 - val_accuracy: 0.5832
#
# Epoch 00004: val_loss improved from 3.71089 to 3.24659, saving model to models/weights.best.Xception.hdf5
# Epoch 5/120
# 6680/6680 [==============================] - 3s 491us/step - loss: 3.0727 - accuracy: 0.5274 - val_loss: 2.7885 - val_accuracy: 0.6287
#
# Epoch 00005: val_loss improved from 3.24659 to 2.78850, saving model to models/weights.best.Xception.hdf5
# Epoch 6/120
# 6680/6680 [==============================] - 3s 504us/step - loss: 2.6575 - accuracy: 0.5802 - val_loss: 2.3776 - val_accuracy: 0.6587
#
# Epoch 00006: val_loss improved from 2.78850 to 2.37760, saving model to models/weights.best.Xception.hdf5
# Epoch 7/120
# 6680/6680 [==============================] - 3s 509us/step - loss: 2.2843 - accuracy: 0.6319 - val_loss: 2.0299 - val_accuracy: 0.7054
#
# Epoch 00007: val_loss improved from 2.37760 to 2.02987, saving model to models/weights.best.Xception.hdf5
# Epoch 8/120
# 6680/6680 [==============================] - 3s 524us/step - loss: 1.9852 - accuracy: 0.6605 - val_loss: 1.7507 - val_accuracy: 0.7305
#
# Epoch 00008: val_loss improved from 2.02987 to 1.75073, saving model to models/weights.best.Xception.hdf5
# Epoch 9/120
# 6680/6680 [==============================] - 4s 541us/step - loss: 1.7470 - accuracy: 0.6885 - val_loss: 1.5306 - val_accuracy: 0.7545
#
# Epoch 00009: val_loss improved from 1.75073 to 1.53060, saving model to models/weights.best.Xception.hdf5
# Epoch 10/120
# 6680/6680 [==============================] - 3s 524us/step - loss: 1.5689 - accuracy: 0.7045 - val_loss: 1.3601 - val_accuracy: 0.7629
#
# Epoch 00010: val_loss improved from 1.53060 to 1.36009, saving model to models/weights.best.Xception.hdf5
# Epoch 11/120
# 6680/6680 [==============================] - 3s 498us/step - loss: 1.4074 - accuracy: 0.7171 - val_loss: 1.2262 - val_accuracy: 0.7832
#
# Epoch 00011: val_loss improved from 1.36009 to 1.22624, saving model to models/weights.best.Xception.hdf5
# Epoch 12/120
# 6680/6680 [==============================] - 3s 494us/step - loss: 1.2905 - accuracy: 0.7340 - val_loss: 1.1199 - val_accuracy: 0.7880
#
# Epoch 00012: val_loss improved from 1.22624 to 1.11991, saving model to models/weights.best.Xception.hdf5
# Epoch 13/120
# 6680/6680 [==============================] - 3s 490us/step - loss: 1.2033 - accuracy: 0.7430 - val_loss: 1.0358 - val_accuracy: 0.7964
#
# Epoch 00013: val_loss improved from 1.11991 to 1.03581, saving model to models/weights.best.Xception.hdf5
# Epoch 14/120
# 6680/6680 [==============================] - 3s 489us/step - loss: 1.1211 - accuracy: 0.7567 - val_loss: 0.9691 - val_accuracy: 0.8036
#
# Epoch 00014: val_loss improved from 1.03581 to 0.96913, saving model to models/weights.best.Xception.hdf5
# Epoch 15/120
# 6680/6680 [==============================] - 3s 488us/step - loss: 1.0528 - accuracy: 0.7629 - val_loss: 0.9133 - val_accuracy: 0.8072
#
# Epoch 00015: val_loss improved from 0.96913 to 0.91326, saving model to models/weights.best.Xception.hdf5
# Epoch 16/120
# 6680/6680 [==============================] - 3s 487us/step - loss: 0.9897 - accuracy: 0.7719 - val_loss: 0.8661 - val_accuracy: 0.8072
#
# Epoch 00016: val_loss improved from 0.91326 to 0.86607, saving model to models/weights.best.Xception.hdf5
# Epoch 17/120
# 6680/6680 [==============================] - 3s 491us/step - loss: 0.9418 - accuracy: 0.7843 - val_loss: 0.8263 - val_accuracy: 0.8132
#
# Epoch 00017: val_loss improved from 0.86607 to 0.82625, saving model to models/weights.best.Xception.hdf5
# Epoch 18/120
# 6680/6680 [==============================] - 3s 490us/step - loss: 0.9051 - accuracy: 0.7883 - val_loss: 0.7921 - val_accuracy: 0.8240
#
# Epoch 00018: val_loss improved from 0.82625 to 0.79211, saving model to models/weights.best.Xception.hdf5
# Epoch 19/120
# 6680/6680 [==============================] - 3s 496us/step - loss: 0.8708 - accuracy: 0.7904 - val_loss: 0.7629 - val_accuracy: 0.8228
#
# Epoch 00019: val_loss improved from 0.79211 to 0.76285, saving model to models/weights.best.Xception.hdf5
# Epoch 20/120
# 6680/6680 [==============================] - 3s 515us/step - loss: 0.8279 - accuracy: 0.7988 - val_loss: 0.7379 - val_accuracy: 0.8240
#
# Epoch 00020: val_loss improved from 0.76285 to 0.73793, saving model to models/weights.best.Xception.hdf5
# Epoch 21/120
# 6680/6680 [==============================] - 3s 486us/step - loss: 0.8064 - accuracy: 0.7999 - val_loss: 0.7154 - val_accuracy: 0.8251
#
# Epoch 00021: val_loss improved from 0.73793 to 0.71539, saving model to models/weights.best.Xception.hdf5
# Epoch 22/120
# 6680/6680 [==============================] - 3s 490us/step - loss: 0.7692 - accuracy: 0.8087 - val_loss: 0.6951 - val_accuracy: 0.8275
#
# Epoch 00022: val_loss improved from 0.71539 to 0.69512, saving model to models/weights.best.Xception.hdf5
# Epoch 23/120
# 6680/6680 [==============================] - 3s 489us/step - loss: 0.7643 - accuracy: 0.8036 - val_loss: 0.6787 - val_accuracy: 0.8371
#
# Epoch 00023: val_loss improved from 0.69512 to 0.67866, saving model to models/weights.best.Xception.hdf5
# Epoch 24/120
# 6680/6680 [==============================] - 3s 489us/step - loss: 0.7290 - accuracy: 0.8163 - val_loss: 0.6625 - val_accuracy: 0.8335
#
# Epoch 00024: val_loss improved from 0.67866 to 0.66249, saving model to models/weights.best.Xception.hdf5
# Epoch 25/120
# 6680/6680 [==============================] - 3s 507us/step - loss: 0.7193 - accuracy: 0.8156 - val_loss: 0.6496 - val_accuracy: 0.8299
#
# Epoch 00025: val_loss improved from 0.66249 to 0.64958, saving model to models/weights.best.Xception.hdf5
# Epoch 26/120
# 6680/6680 [==============================] - 3s 522us/step - loss: 0.6933 - accuracy: 0.8234 - val_loss: 0.6379 - val_accuracy: 0.8299
#
# Epoch 00026: val_loss improved from 0.64958 to 0.63788, saving model to models/weights.best.Xception.hdf5
# Epoch 27/120
# 6680/6680 [==============================] - 3s 494us/step - loss: 0.6914 - accuracy: 0.8207 - val_loss: 0.6264 - val_accuracy: 0.8347
#
# Epoch 00027: val_loss improved from 0.63788 to 0.62643, saving model to models/weights.best.Xception.hdf5
# Epoch 28/120
# 6680/6680 [==============================] - 3s 508us/step - loss: 0.6698 - accuracy: 0.8190 - val_loss: 0.6180 - val_accuracy: 0.8359
#
# Epoch 00028: val_loss improved from 0.62643 to 0.61802, saving model to models/weights.best.Xception.hdf5
# Epoch 29/120
# 6680/6680 [==============================] - 3s 497us/step - loss: 0.6388 - accuracy: 0.8304 - val_loss: 0.6074 - val_accuracy: 0.8371
#
# Epoch 00029: val_loss improved from 0.61802 to 0.60739, saving model to models/weights.best.Xception.hdf5
# Epoch 30/120
# 6680/6680 [==============================] - 3s 499us/step - loss: 0.6396 - accuracy: 0.8289 - val_loss: 0.5992 - val_accuracy: 0.8371
#
# Epoch 00030: val_loss improved from 0.60739 to 0.59918, saving model to models/weights.best.Xception.hdf5
# Epoch 31/120
# 6680/6680 [==============================] - 3s 499us/step - loss: 0.6159 - accuracy: 0.8353 - val_loss: 0.5902 - val_accuracy: 0.8383
#
# Epoch 00031: val_loss improved from 0.59918 to 0.59022, saving model to models/weights.best.Xception.hdf5
# Epoch 32/120
# 6680/6680 [==============================] - 3s 497us/step - loss: 0.6164 - accuracy: 0.8328 - val_loss: 0.5841 - val_accuracy: 0.8371
#
# Epoch 00032: val_loss improved from 0.59022 to 0.58409, saving model to models/weights.best.Xception.hdf5
# Epoch 33/120
# 6680/6680 [==============================] - 3s 498us/step - loss: 0.5975 - accuracy: 0.8427 - val_loss: 0.5769 - val_accuracy: 0.8371
#
# Epoch 00033: val_loss improved from 0.58409 to 0.57690, saving model to models/weights.best.Xception.hdf5
# Epoch 34/120
# 6680/6680 [==============================] - 3s 507us/step - loss: 0.5847 - accuracy: 0.8407 - val_loss: 0.5709 - val_accuracy: 0.8419
#
# Epoch 00034: val_loss improved from 0.57690 to 0.57093, saving model to models/weights.best.Xception.hdf5
# Epoch 35/120
# 6680/6680 [==============================] - 3s 513us/step - loss: 0.5823 - accuracy: 0.8449 - val_loss: 0.5658 - val_accuracy: 0.8407
#
# Epoch 00035: val_loss improved from 0.57093 to 0.56579, saving model to models/weights.best.Xception.hdf5
# Epoch 36/120
# 6680/6680 [==============================] - 3s 514us/step - loss: 0.5698 - accuracy: 0.8449 - val_loss: 0.5607 - val_accuracy: 0.8431
#
# Epoch 00036: val_loss improved from 0.56579 to 0.56072, saving model to models/weights.best.Xception.hdf5
# Epoch 37/120
# 6680/6680 [==============================] - 3s 519us/step - loss: 0.5640 - accuracy: 0.8507 - val_loss: 0.5557 - val_accuracy: 0.8443
#
# Epoch 00037: val_loss improved from 0.56072 to 0.55572, saving model to models/weights.best.Xception.hdf5
# Epoch 38/120
# 6680/6680 [==============================] - 3s 508us/step - loss: 0.5545 - accuracy: 0.8448 - val_loss: 0.5501 - val_accuracy: 0.8395
#
# Epoch 00038: val_loss improved from 0.55572 to 0.55009, saving model to models/weights.best.Xception.hdf5
# Epoch 39/120
# 6680/6680 [==============================] - 3s 512us/step - loss: 0.5423 - accuracy: 0.8548 - val_loss: 0.5445 - val_accuracy: 0.8395
#
# Epoch 00039: val_loss improved from 0.55009 to 0.54445, saving model to models/weights.best.Xception.hdf5
# Epoch 40/120
# 6680/6680 [==============================] - 3s 507us/step - loss: 0.5384 - accuracy: 0.8524 - val_loss: 0.5404 - val_accuracy: 0.8443
#
# Epoch 00040: val_loss improved from 0.54445 to 0.54041, saving model to models/weights.best.Xception.hdf5
# Epoch 41/120
# 6680/6680 [==============================] - 3s 509us/step - loss: 0.5324 - accuracy: 0.8525 - val_loss: 0.5368 - val_accuracy: 0.8431
#
# Epoch 00041: val_loss improved from 0.54041 to 0.53676, saving model to models/weights.best.Xception.hdf5
# Epoch 42/120
# 6680/6680 [==============================] - 3s 505us/step - loss: 0.5200 - accuracy: 0.8569 - val_loss: 0.5329 - val_accuracy: 0.8383
#
# Epoch 00042: val_loss improved from 0.53676 to 0.53290, saving model to models/weights.best.Xception.hdf5
# Epoch 43/120
# 6680/6680 [==============================] - 3s 521us/step - loss: 0.5218 - accuracy: 0.8563 - val_loss: 0.5289 - val_accuracy: 0.8419
#
# Epoch 00043: val_loss improved from 0.53290 to 0.52894, saving model to models/weights.best.Xception.hdf5
# Epoch 44/120
# 6680/6680 [==============================] - 3s 513us/step - loss: 0.5121 - accuracy: 0.8588 - val_loss: 0.5260 - val_accuracy: 0.8395
#
# Epoch 00044: val_loss improved from 0.52894 to 0.52602, saving model to models/weights.best.Xception.hdf5
# Epoch 45/120
# 6680/6680 [==============================] - 3s 504us/step - loss: 0.5052 - accuracy: 0.8563 - val_loss: 0.5234 - val_accuracy: 0.8443
#
# Epoch 00045: val_loss improved from 0.52602 to 0.52335, saving model to models/weights.best.Xception.hdf5
# Epoch 46/120
# 6680/6680 [==============================] - 3s 504us/step - loss: 0.4963 - accuracy: 0.8632 - val_loss: 0.5214 - val_accuracy: 0.8407
#
# Epoch 00046: val_loss improved from 0.52335 to 0.52140, saving model to models/weights.best.Xception.hdf5
# Epoch 47/120
# 6680/6680 [==============================] - 3s 511us/step - loss: 0.4920 - accuracy: 0.8611 - val_loss: 0.5181 - val_accuracy: 0.8491
#
# Epoch 00047: val_loss improved from 0.52140 to 0.51814, saving model to models/weights.best.Xception.hdf5
# Epoch 48/120
# 6680/6680 [==============================] - 3s 516us/step - loss: 0.4917 - accuracy: 0.8632 - val_loss: 0.5134 - val_accuracy: 0.8419
#
# Epoch 00048: val_loss improved from 0.51814 to 0.51345, saving model to models/weights.best.Xception.hdf5
# Epoch 49/120
# 6680/6680 [==============================] - 3s 505us/step - loss: 0.4786 - accuracy: 0.8677 - val_loss: 0.5116 - val_accuracy: 0.8443
#
# Epoch 00049: val_loss improved from 0.51345 to 0.51158, saving model to models/weights.best.Xception.hdf5
# Epoch 50/120
# 6680/6680 [==============================] - 3s 503us/step - loss: 0.4663 - accuracy: 0.8675 - val_loss: 0.5070 - val_accuracy: 0.8455
#
# Epoch 00050: val_loss improved from 0.51158 to 0.50701, saving model to models/weights.best.Xception.hdf5
# Epoch 51/120
# 6680/6680 [==============================] - 3s 520us/step - loss: 0.4736 - accuracy: 0.8723 - val_loss: 0.5049 - val_accuracy: 0.8491
#
# Epoch 00051: val_loss improved from 0.50701 to 0.50491, saving model to models/weights.best.Xception.hdf5
# Epoch 52/120
# 6680/6680 [==============================] - 3s 517us/step - loss: 0.4637 - accuracy: 0.8710 - val_loss: 0.5031 - val_accuracy: 0.8515
#
# Epoch 00052: val_loss improved from 0.50491 to 0.50314, saving model to models/weights.best.Xception.hdf5
# Epoch 53/120
# 6680/6680 [==============================] - 4s 543us/step - loss: 0.4601 - accuracy: 0.8750 - val_loss: 0.5006 - val_accuracy: 0.8491
#
# Epoch 00053: val_loss improved from 0.50314 to 0.50062, saving model to models/weights.best.Xception.hdf5
# Epoch 54/120
# 6680/6680 [==============================] - 4s 543us/step - loss: 0.4494 - accuracy: 0.8720 - val_loss: 0.4989 - val_accuracy: 0.8455
#
# Epoch 00054: val_loss improved from 0.50062 to 0.49889, saving model to models/weights.best.Xception.hdf5
# Epoch 55/120
# 6680/6680 [==============================] - 4s 548us/step - loss: 0.4531 - accuracy: 0.8743 - val_loss: 0.4974 - val_accuracy: 0.8467
#
# Epoch 00055: val_loss improved from 0.49889 to 0.49743, saving model to models/weights.best.Xception.hdf5
# Epoch 56/120
# 6680/6680 [==============================] - 4s 585us/step - loss: 0.4474 - accuracy: 0.8732 - val_loss: 0.4967 - val_accuracy: 0.8431
#
# Epoch 00056: val_loss improved from 0.49743 to 0.49670, saving model to models/weights.best.Xception.hdf5
# Epoch 57/120
# 6680/6680 [==============================] - 4s 536us/step - loss: 0.4413 - accuracy: 0.8759 - val_loss: 0.4934 - val_accuracy: 0.8479
#
# Epoch 00057: val_loss improved from 0.49670 to 0.49344, saving model to models/weights.best.Xception.hdf5
# Epoch 58/120
# 6680/6680 [==============================] - 3s 521us/step - loss: 0.4352 - accuracy: 0.8795 - val_loss: 0.4921 - val_accuracy: 0.8467
#
# Epoch 00058: val_loss improved from 0.49344 to 0.49205, saving model to models/weights.best.Xception.hdf5
# Epoch 59/120
# 6680/6680 [==============================] - 3s 522us/step - loss: 0.4328 - accuracy: 0.8753 - val_loss: 0.4890 - val_accuracy: 0.8491
#
# Epoch 00059: val_loss improved from 0.49205 to 0.48896, saving model to models/weights.best.Xception.hdf5
# Epoch 60/120
# 6680/6680 [==============================] - 3s 507us/step - loss: 0.4254 - accuracy: 0.8801 - val_loss: 0.4894 - val_accuracy: 0.8455
#
# Epoch 00060: val_loss did not improve from 0.48896
# Epoch 61/120
# 6680/6680 [==============================] - 3s 511us/step - loss: 0.4178 - accuracy: 0.8813 - val_loss: 0.4866 - val_accuracy: 0.8467
#
# Epoch 00061: val_loss improved from 0.48896 to 0.48660, saving model to models/weights.best.Xception.hdf5
# Epoch 62/120
# 6680/6680 [==============================] - 3s 510us/step - loss: 0.4212 - accuracy: 0.8778 - val_loss: 0.4842 - val_accuracy: 0.8455
#
# Epoch 00062: val_loss improved from 0.48660 to 0.48417, saving model to models/weights.best.Xception.hdf5
# Epoch 63/120
# 6680/6680 [==============================] - 4s 529us/step - loss: 0.4109 - accuracy: 0.8840 - val_loss: 0.4825 - val_accuracy: 0.8491
#
# Epoch 00063: val_loss improved from 0.48417 to 0.48246, saving model to models/weights.best.Xception.hdf5
# Epoch 64/120
# 6680/6680 [==============================] - 3s 509us/step - loss: 0.4068 - accuracy: 0.8871 - val_loss: 0.4806 - val_accuracy: 0.8503
#
# Epoch 00064: val_loss improved from 0.48246 to 0.48065, saving model to models/weights.best.Xception.hdf5
# Epoch 65/120
# 6680/6680 [==============================] - 3s 504us/step - loss: 0.4188 - accuracy: 0.8777 - val_loss: 0.4791 - val_accuracy: 0.8491
# Epoch 00065: val_loss improved from 0.48065 to 0.47907, saving model to models/weights.best.Xception.hdf5
# Epoch 66/120
# 6680/6680 [==============================] - 4s 529us/step - loss: 0.4031 - accuracy: 0.8847 - val_loss: 0.4790 - val_accuracy: 0.8491
#
# Epoch 00066: val_loss improved from 0.47907 to 0.47902, saving model to models/weights.best.Xception.hdf5
# Epoch 67/120
# 6680/6680 [==============================] - 3s 497us/step - loss: 0.4037 - accuracy: 0.8841 - val_loss: 0.4790 - val_accuracy: 0.8491
#
# Epoch 00067: val_loss improved from 0.47902 to 0.47897, saving model to models/weights.best.Xception.hdf5
# Epoch 68/120
# 6680/6680 [==============================] - 3s 515us/step - loss: 0.3928 - accuracy: 0.8909 - val_loss: 0.4752 - val_accuracy: 0.8491
#
# Epoch 00068: val_loss improved from 0.47897 to 0.47519, saving model to models/weights.best.Xception.hdf5
# Epoch 69/120
# 6680/6680 [==============================] - 3s 519us/step - loss: 0.3983 - accuracy: 0.8865 - val_loss: 0.4750 - val_accuracy: 0.8491
#
# Epoch 00069: val_loss improved from 0.47519 to 0.47500, saving model to models/weights.best.Xception.hdf5
# Epoch 70/120
# 6680/6680 [==============================] - 3s 514us/step - loss: 0.3901 - accuracy: 0.8918 - val_loss: 0.4744 - val_accuracy: 0.8527
#
# Epoch 00070: val_loss improved from 0.47500 to 0.47435, saving model to models/weights.best.Xception.hdf5
# Epoch 71/120
# 6680/6680 [==============================] - 4s 529us/step - loss: 0.3824 - accuracy: 0.8898 - val_loss: 0.4726 - val_accuracy: 0.8479
#
# Epoch 00071: val_loss improved from 0.47435 to 0.47264, saving model to models/weights.best.Xception.hdf5
# Epoch 72/120
# 6680/6680 [==============================] - 4s 534us/step - loss: 0.3860 - accuracy: 0.8876 - val_loss: 0.4714 - val_accuracy: 0.8503
#
# Epoch 00072: val_loss improved from 0.47264 to 0.47141, saving model to models/weights.best.Xception.hdf5
# Epoch 73/120
# 6680/6680 [==============================] - 4s 528us/step - loss: 0.3878 - accuracy: 0.8865 - val_loss: 0.4704 - val_accuracy: 0.8467
#
# Epoch 00073: val_loss improved from 0.47141 to 0.47040, saving model to models/weights.best.Xception.hdf5
# Epoch 74/120
# 6680/6680 [==============================] - 3s 523us/step - loss: 0.3750 - accuracy: 0.8961 - val_loss: 0.4710 - val_accuracy: 0.8503
#
# Epoch 00074: val_loss did not improve from 0.47040
# Epoch 75/120
# 6680/6680 [==============================] - 4s 526us/step - loss: 0.3724 - accuracy: 0.8918 - val_loss: 0.4693 - val_accuracy: 0.8515
#
# Epoch 00075: val_loss improved from 0.47040 to 0.46933, saving model to models/weights.best.Xception.hdf5
# Epoch 76/120
# 6680/6680 [==============================] - 3s 498us/step - loss: 0.3792 - accuracy: 0.8955 - val_loss: 0.4682 - val_accuracy: 0.8491
#
# Epoch 00076: val_loss improved from 0.46933 to 0.46822, saving model to models/weights.best.Xception.hdf5
# Epoch 77/120
# 6680/6680 [==============================] - 3s 491us/step - loss: 0.3645 - accuracy: 0.8984 - val_loss: 0.4655 - val_accuracy: 0.8527
#
# Epoch 00077: val_loss improved from 0.46822 to 0.46550, saving model to models/weights.best.Xception.hdf5
# Epoch 78/120
# 6680/6680 [==============================] - 3s 499us/step - loss: 0.3716 - accuracy: 0.8934 - val_loss: 0.4650 - val_accuracy: 0.8539
#
# Epoch 00078: val_loss improved from 0.46550 to 0.46496, saving model to models/weights.best.Xception.hdf5
# Epoch 79/120
# 6680/6680 [==============================] - 3s 492us/step - loss: 0.3669 - accuracy: 0.8942 - val_loss: 0.4648 - val_accuracy: 0.8539
#
# Epoch 00079: val_loss improved from 0.46496 to 0.46476, saving model to models/weights.best.Xception.hdf5
# Epoch 80/120
# 6680/6680 [==============================] - 3s 512us/step - loss: 0.3586 - accuracy: 0.8990 - val_loss: 0.4652 - val_accuracy: 0.8479
#
# Epoch 00080: val_loss did not improve from 0.46476
# Epoch 81/120
# 6680/6680 [==============================] - 3s 508us/step - loss: 0.3510 - accuracy: 0.8987 - val_loss: 0.4639 - val_accuracy: 0.8539
#
# Epoch 00081: val_loss improved from 0.46476 to 0.46393, saving model to models/weights.best.Xception.hdf5
# Epoch 82/120
# 6680/6680 [==============================] - 3s 521us/step - loss: 0.3505 - accuracy: 0.9016 - val_loss: 0.4630 - val_accuracy: 0.8515
#
# Epoch 00082: val_loss improved from 0.46393 to 0.46295, saving model to models/weights.best.Xception.hdf5
# Epoch 83/120
# 6680/6680 [==============================] - 4s 529us/step - loss: 0.3448 - accuracy: 0.9006 - val_loss: 0.4625 - val_accuracy: 0.8503
#
# Epoch 00083: val_loss improved from 0.46295 to 0.46252, saving model to models/weights.best.Xception.hdf5
# Epoch 84/120
# 6680/6680 [==============================] - 3s 523us/step - loss: 0.3534 - accuracy: 0.8979 - val_loss: 0.4620 - val_accuracy: 0.8515
#
# Epoch 00084: val_loss improved from 0.46252 to 0.46205, saving model to models/weights.best.Xception.hdf5
# Epoch 85/120
# 6680/6680 [==============================] - 4s 524us/step - loss: 0.3440 - accuracy: 0.9013 - val_loss: 0.4603 - val_accuracy: 0.8539
#
# Epoch 00085: val_loss improved from 0.46205 to 0.46034, saving model to models/weights.best.Xception.hdf5
# Epoch 86/120
# 6680/6680 [==============================] - 4s 540us/step - loss: 0.3446 - accuracy: 0.9010 - val_loss: 0.4605 - val_accuracy: 0.8539
#
# Epoch 00086: val_loss did not improve from 0.46034
# Epoch 87/120
# 6680/6680 [==============================] - 3s 497us/step - loss: 0.3355 - accuracy: 0.9048 - val_loss: 0.4589 - val_accuracy: 0.8527
#
# Epoch 00087: val_loss improved from 0.46034 to 0.45889, saving model to models/weights.best.Xception.hdf5
# Epoch 88/120
# 6680/6680 [==============================] - 4s 525us/step - loss: 0.3362 - accuracy: 0.9007 - val_loss: 0.4582 - val_accuracy: 0.8539
#
# Epoch 00088: val_loss improved from 0.45889 to 0.45820, saving model to models/weights.best.Xception.hdf5
# Epoch 89/120
# 6680/6680 [==============================] - 3s 515us/step - loss: 0.3395 - accuracy: 0.9084 - val_loss: 0.4572 - val_accuracy: 0.8515
#
# Epoch 00089: val_loss improved from 0.45820 to 0.45723, saving model to models/weights.best.Xception.hdf5
# Epoch 90/120
# 6680/6680 [==============================] - 3s 511us/step - loss: 0.3304 - accuracy: 0.9036 - val_loss: 0.4552 - val_accuracy: 0.8599
#
# Epoch 00090: val_loss improved from 0.45723 to 0.45522, saving model to models/weights.best.Xception.hdf5
# Epoch 91/120
# 6680/6680 [==============================] - 4s 535us/step - loss: 0.3274 - accuracy: 0.9073 - val_loss: 0.4544 - val_accuracy: 0.8551
#
# Epoch 00091: val_loss improved from 0.45522 to 0.45438, saving model to models/weights.best.Xception.hdf5
# Epoch 92/120
# 6680/6680 [==============================] - 3s 502us/step - loss: 0.3315 - accuracy: 0.9015 - val_loss: 0.4546 - val_accuracy: 0.8539
#
# Epoch 00092: val_loss did not improve from 0.45438
# Epoch 93/120
# 6680/6680 [==============================] - 3s 506us/step - loss: 0.3237 - accuracy: 0.9064 - val_loss: 0.4551 - val_accuracy: 0.8503
#
# Epoch 00093: val_loss did not improve from 0.45438
# Epoch 94/120
# 6680/6680 [==============================] - 3s 492us/step - loss: 0.3232 - accuracy: 0.9124 - val_loss: 0.4528 - val_accuracy: 0.8527
#
# Epoch 00094: val_loss improved from 0.45438 to 0.45282, saving model to models/weights.best.Xception.hdf5
# Epoch 95/120
# 6680/6680 [==============================] - 3s 508us/step - loss: 0.3241 - accuracy: 0.9028 - val_loss: 0.4533 - val_accuracy: 0.8551
#
# Epoch 00095: val_loss did not improve from 0.45282
# Epoch 96/120
# 6680/6680 [==============================] - 4s 562us/step - loss: 0.3226 - accuracy: 0.9054 - val_loss: 0.4513 - val_accuracy: 0.8587
#
# Epoch 00096: val_loss improved from 0.45282 to 0.45132, saving model to models/weights.best.Xception.hdf5
# Epoch 97/120
# 6680/6680 [==============================] - 3s 494us/step - loss: 0.3157 - accuracy: 0.9114 - val_loss: 0.4513 - val_accuracy: 0.8575
#
# Epoch 00097: val_loss improved from 0.45132 to 0.45129, saving model to models/weights.best.Xception.hdf5
# Epoch 98/120
# 6680/6680 [==============================] - 3s 491us/step - loss: 0.3167 - accuracy: 0.9076 - val_loss: 0.4506 - val_accuracy: 0.8563
#
# Epoch 00098: val_loss improved from 0.45129 to 0.45057, saving model to models/weights.best.Xception.hdf5
# Epoch 99/120
# 6680/6680 [==============================] - 3s 503us/step - loss: 0.3184 - accuracy: 0.9091 - val_loss: 0.4503 - val_accuracy: 0.8539
#
# Epoch 00099: val_loss improved from 0.45057 to 0.45033, saving model to models/weights.best.Xception.hdf5
# Epoch 100/120
# 6680/6680 [==============================] - 3s 517us/step - loss: 0.3205 - accuracy: 0.9064 - val_loss: 0.4487 - val_accuracy: 0.8539
#
# Epoch 00100: val_loss improved from 0.45033 to 0.44874, saving model to models/weights.best.Xception.hdf5
# Epoch 101/120
# 6680/6680 [==============================] - 3s 523us/step - loss: 0.3194 - accuracy: 0.9072 - val_loss: 0.4497 - val_accuracy: 0.8551
#
# Epoch 00101: val_loss did not improve from 0.44874
# Epoch 102/120
# 6680/6680 [==============================] - 4s 531us/step - loss: 0.3136 - accuracy: 0.9112 - val_loss: 0.4495 - val_accuracy: 0.8539
#
# Epoch 00102: val_loss did not improve from 0.44874
# Epoch 103/120
# 6680/6680 [==============================] - 3s 501us/step - loss: 0.3079 - accuracy: 0.9136 - val_loss: 0.4491 - val_accuracy: 0.8563
#
# Epoch 00103: val_loss did not improve from 0.44874
# Epoch 104/120
# 6680/6680 [==============================] - 3s 510us/step - loss: 0.3092 - accuracy: 0.9135 - val_loss: 0.4482 - val_accuracy: 0.8539
#
# Epoch 00104: val_loss improved from 0.44874 to 0.44820, saving model to models/weights.best.Xception.hdf5
# Epoch 105/120
# 6680/6680 [==============================] - 3s 517us/step - loss: 0.2976 - accuracy: 0.9177 - val_loss: 0.4468 - val_accuracy: 0.8551
#
# Epoch 00105: val_loss improved from 0.44820 to 0.44680, saving model to models/weights.best.Xception.hdf5
# Epoch 106/120
# 6680/6680 [==============================] - 3s 493us/step - loss: 0.3050 - accuracy: 0.9138 - val_loss: 0.4447 - val_accuracy: 0.8551
#
# Epoch 00106: val_loss improved from 0.44680 to 0.44465, saving model to models/weights.best.Xception.hdf5
# Epoch 107/120
# 6680/6680 [==============================] - 3s 507us/step - loss: 0.2987 - accuracy: 0.9123 - val_loss: 0.4443 - val_accuracy: 0.8563
#
# Epoch 00107: val_loss improved from 0.44465 to 0.44427, saving model to models/weights.best.Xception.hdf5
# Epoch 108/120
# 6680/6680 [==============================] - 3s 492us/step - loss: 0.2951 - accuracy: 0.9169 - val_loss: 0.4440 - val_accuracy: 0.8551
#
# Epoch 00108: val_loss improved from 0.44427 to 0.44403, saving model to models/weights.best.Xception.hdf5
# Epoch 109/120
# 6680/6680 [==============================] - 3s 501us/step - loss: 0.2982 - accuracy: 0.9133 - val_loss: 0.4435 - val_accuracy: 0.8575
#
# Epoch 00109: val_loss improved from 0.44403 to 0.44354, saving model to models/weights.best.Xception.hdf5
# Epoch 110/120
# 6680/6680 [==============================] - 3s 491us/step - loss: 0.2918 - accuracy: 0.9201 - val_loss: 0.4441 - val_accuracy: 0.8539
#
# Epoch 00110: val_loss did not improve from 0.44354
# Epoch 111/120
# 6680/6680 [==============================] - 3s 498us/step - loss: 0.2915 - accuracy: 0.9151 - val_loss: 0.4434 - val_accuracy: 0.8551
#
# Epoch 00111: val_loss improved from 0.44354 to 0.44343, saving model to models/weights.best.Xception.hdf5
# Epoch 112/120
# 6680/6680 [==============================] - 3s 510us/step - loss: 0.2978 - accuracy: 0.9132 - val_loss: 0.4424 - val_accuracy: 0.8587
#
# Epoch 00112: val_loss improved from 0.44343 to 0.44240, saving model to models/weights.best.Xception.hdf5
# Epoch 113/120
# 6680/6680 [==============================] - 3s 519us/step - loss: 0.2902 - accuracy: 0.9159 - val_loss: 0.4418 - val_accuracy: 0.8575
#
# Epoch 00113: val_loss improved from 0.44240 to 0.44176, saving model to models/weights.best.Xception.hdf5
# Epoch 114/120
# 6680/6680 [==============================] - 3s 498us/step - loss: 0.2830 - accuracy: 0.9199 - val_loss: 0.4426 - val_accuracy: 0.8563
#
# Epoch 00114: val_loss did not improve from 0.44176
# Epoch 115/120
# 6680/6680 [==============================] - 3s 506us/step - loss: 0.2921 - accuracy: 0.9129 - val_loss: 0.4432 - val_accuracy: 0.8563
#
# Epoch 00115: val_loss did not improve from 0.44176
# Epoch 116/120
# 6680/6680 [==============================] - 3s 507us/step - loss: 0.2806 - accuracy: 0.9193 - val_loss: 0.4436 - val_accuracy: 0.8539
#
# Epoch 00116: val_loss did not improve from 0.44176
# Epoch 117/120
# 6680/6680 [==============================] - 3s 510us/step - loss: 0.2808 - accuracy: 0.9184 - val_loss: 0.4444 - val_accuracy: 0.8539
#
# Epoch 00117: val_loss did not improve from 0.44176
# Epoch 118/120
# 6680/6680 [==============================] - 4s 527us/step - loss: 0.2806 - accuracy: 0.9205 - val_loss: 0.4443 - val_accuracy: 0.8527
#
# Epoch 00118: val_loss did not improve from 0.44176
# Epoch 119/120
# 6680/6680 [==============================] - 4s 524us/step - loss: 0.2725 - accuracy: 0.9217 - val_loss: 0.4431 - val_accuracy: 0.8551
#
# Epoch 00119: val_loss did not improve from 0.44176
# Epoch 120/120
# 6680/6680 [==============================] - 4s 542us/step - loss: 0.2761 - accuracy: 0.9205 - val_loss: 0.4428 - val_accuracy: 0.8563
#
# Epoch 00120: val_loss did not improve from 0.44176

# %%
testModel(xceptionModel,test_Xception,test_targets,test_target_names)
# Out:
# Test accuracy: 84.8086%
#                                     precision    recall  f1-score   support
#
#                      Affenpinscher       0.88      0.88      0.88         8
#                       Afghan_hound       0.88      0.88      0.88         8
#                   Airedale_terrier       1.00      1.00      1.00         6
#                              Akita       1.00      0.88      0.93         8
#                   Alaskan_malamute       0.91      1.00      0.95        10
#                American_eskimo_dog       1.00      1.00      1.00         8
#                  American_foxhound       1.00      0.86      0.92         7
#     American_staffordshire_terrier       1.00      1.00      1.00         8
#             American_water_spaniel       1.00      0.50      0.67         4
#             Anatolian_shepherd_dog       0.86      1.00      0.92         6
#              Australian_cattle_dog       1.00      1.00      1.00         9
#                Australian_shepherd       1.00      0.89      0.94         9
#                 Australian_terrier       0.80      0.67      0.73         6
#                            Basenji       0.89      0.89      0.89         9
#                       Basset_hound       0.91      1.00      0.95        10
#                             Beagle       0.88      0.88      0.88         8
#                     Bearded_collie       0.58      0.88      0.70         8
#                          Beauceron       1.00      1.00      1.00         7
#                 Bedlington_terrier       1.00      1.00      1.00         6
#                   Belgian_malinois       0.89      1.00      0.94         8
#                   Belgian_sheepdog       0.60      0.75      0.67         8
#                   Belgian_tervuren       1.00      0.50      0.67         6
#               Bernese_mountain_dog       1.00      1.00      1.00         8
#                       Bichon_frise       0.89      1.00      0.94         8
#            Black_and_tan_coonhound       1.00      1.00      1.00         4
#              Black_russian_terrier       0.75      0.60      0.67         5
#                         Bloodhound       1.00      1.00      1.00         8
#                 Bluetick_coonhound       1.00      0.75      0.86         4
#                      Border_collie       1.00      1.00      1.00        10
#                     Border_terrier       1.00      1.00      1.00         7
#                             Borzoi       0.88      1.00      0.93         7
#                     Boston_terrier       1.00      1.00      1.00         8
#               Bouvier_des_flandres       0.80      0.80      0.80         5
#                              Boxer       1.00      1.00      1.00         8
#                     Boykin_spaniel       0.50      1.00      0.67         6
#                             Briard       1.00      1.00      1.00         8
#                           Brittany       0.80      0.67      0.73         6
#                   Brussels_griffon       1.00      0.86      0.92         7
#                       Bull_terrier       1.00      0.89      0.94         9
#                            Bulldog       0.88      1.00      0.93         7
#                        Bullmastiff       0.64      0.78      0.70         9
#                      Cairn_terrier       1.00      1.00      1.00         8
#                         Canaan_dog       0.75      1.00      0.86         6
#                         Cane_corso       0.86      0.75      0.80         8
#               Cardigan_welsh_corgi       0.83      0.71      0.77         7
#      Cavalier_king_charles_spaniel       0.67      0.89      0.76         9
#           Chesapeake_bay_retriever       1.00      1.00      1.00         7
#                          Chihuahua       0.83      0.71      0.77         7
#                    Chinese_crested       1.00      1.00      1.00         6
#                   Chinese_shar-pei       1.00      0.67      0.80         6
#                          Chow_chow       0.88      0.88      0.88         8
#                    Clumber_spaniel       1.00      0.83      0.91         6
#                     Cocker_spaniel       0.62      0.83      0.71         6
#                             Collie       1.00      0.86      0.92         7
#             Curly-coated_retriever       1.00      1.00      1.00         7
#                          Dachshund       1.00      0.78      0.88         9
#                          Dalmatian       1.00      1.00      1.00         9
#             Dandie_dinmont_terrier       1.00      1.00      1.00         7
#                  Doberman_pinscher       0.71      0.83      0.77         6
#                  Dogue_de_bordeaux       0.78      0.88      0.82         8
#             English_cocker_spaniel       1.00      0.38      0.55         8
#                     English_setter       0.86      1.00      0.92         6
#           English_springer_spaniel       0.71      0.71      0.71         7
#                English_toy_spaniel       1.00      0.60      0.75         5
#           Entlebucher_mountain_dog       1.00      0.80      0.89         5
#                      Field_spaniel       1.00      1.00      1.00         4
#                      Finnish_spitz       1.00      0.50      0.67         4
#              Flat-coated_retriever       0.88      0.88      0.88         8
#                     French_bulldog       0.88      1.00      0.93         7
#                    German_pinscher       0.50      0.67      0.57         6
#                German_shepherd_dog       0.88      0.88      0.88         8
#         German_shorthaired_pointer       0.62      0.83      0.71         6
#          German_wirehaired_pointer       1.00      0.40      0.57         5
#                    Giant_schnauzer       0.60      0.60      0.60         5
#              Glen_of_imaal_terrier       1.00      0.80      0.89         5
#                   Golden_retriever       0.70      0.88      0.78         8
#                      Gordon_setter       0.83      1.00      0.91         5
#                         Great_dane       1.00      0.40      0.57         5
#                     Great_pyrenees       0.78      0.88      0.82         8
#         Greater_swiss_mountain_dog       0.83      1.00      0.91         5
#                          Greyhound       0.75      0.86      0.80         7
#                           Havanese       0.56      0.62      0.59         8
#                       Ibizan_hound       1.00      1.00      1.00         6
#                 Icelandic_sheepdog       0.57      0.67      0.62         6
#         Irish_red_and_white_setter       0.43      0.75      0.55         4
#                       Irish_setter       1.00      1.00      1.00         7
#                      Irish_terrier       0.89      1.00      0.94         8
#                Irish_water_spaniel       0.83      0.83      0.83         6
#                    Irish_wolfhound       0.67      0.86      0.75         7
#                  Italian_greyhound       0.88      0.88      0.88         8
#                      Japanese_chin       1.00      1.00      1.00         7
#                           Keeshond       1.00      1.00      1.00         5
#                 Kerry_blue_terrier       0.67      0.50      0.57         4
#                           Komondor       1.00      1.00      1.00         5
#                             Kuvasz       1.00      0.50      0.67         6
#                 Labrador_retriever       0.80      0.80      0.80         5
#                   Lakeland_terrier       0.83      0.83      0.83         6
#                         Leonberger       1.00      1.00      1.00         5
#                         Lhasa_apso       0.60      0.60      0.60         5
#                            Lowchen       0.33      0.25      0.29         4
#                            Maltese       1.00      0.83      0.91         6
#                 Manchester_terrier       1.00      0.33      0.50         3
#                            Mastiff       0.83      0.71      0.77         7
#                Miniature_schnauzer       1.00      1.00      1.00         5
#                 Neapolitan_mastiff       1.00      1.00      1.00         4
#                       Newfoundland       0.80      0.67      0.73         6
#                    Norfolk_terrier       0.71      0.83      0.77         6
#                   Norwegian_buhund       0.00      0.00      0.00         3
#                 Norwegian_elkhound       0.83      1.00      0.91         5
#                Norwegian_lundehund       0.67      1.00      0.80         4
#                    Norwich_terrier       0.67      0.80      0.73         5
# Nova_scotia_duck_tolling_retriever       0.88      1.00      0.93         7
#               Old_english_sheepdog       1.00      0.60      0.75         5
#                         Otterhound       1.00      0.75      0.86         4
#                           Papillon       1.00      1.00      1.00         8
#             Parson_russell_terrier       1.00      1.00      1.00         4
#                          Pekingese       1.00      1.00      1.00         6
#               Pembroke_welsh_corgi       0.86      0.86      0.86         7
#       Petit_basset_griffon_vendeen       1.00      1.00      1.00         4
#                      Pharaoh_hound       1.00      1.00      1.00         5
#                              Plott       0.67      0.67      0.67         3
#                            Pointer       0.50      0.50      0.50         4
#                         Pomeranian       0.71      1.00      0.83         5
#                             Poodle       0.62      0.83      0.71         6
#               Portuguese_water_dog       0.50      0.50      0.50         4
#                      Saint_bernard       1.00      1.00      1.00         3
#                      Silky_terrier       1.00      0.40      0.57         5
#                 Smooth_fox_terrier       1.00      0.50      0.67         4
#                    Tibetan_mastiff       1.00      0.83      0.91         6
#             Welsh_springer_spaniel       0.33      0.20      0.25         5
#        Wirehaired_pointing_griffon       0.60      1.00      0.75         3
#                     Xoloitzcuintli       1.00      1.00      1.00         3
#                  Yorkshire_terrier       0.60      0.75      0.67         4
#
#                           accuracy                           0.85       836
#                          macro avg       0.86      0.83      0.83       836
#                       weighted avg       0.87      0.85      0.84       836

# %%
testImage = 'dogImages/test/Akita/Akita_00258.jpg'
label = predict(xceptionModel,testImage)
print('Predicted breed is :',label)
# Out:
# Features Generated:  (1, 7, 7, 2048)
# Predicted breed is : Akita
